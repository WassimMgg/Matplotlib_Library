# %% [markdown]
# # Inroduction to Matplotlib

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
plt.show() # You could use plt.show() if you want

# %%
plt.plot([1 ,2, 3, 4])

# %%
x = [1 ,2, 3, 4]
y = [11 ,22, 33, 44]
plt.plot(x , y)

# %%
# 1st method
# Creating a plot with the object-oriented verison
fig = plt.figure() # Create a figure 
ax =fig.add_subplot() # Add some axis 
plt.show()

# %%
# 2nd Method 
fig = plt.figure() # Create a figure 
ax = fig.add_axes([1, 1,1,1])
ax.plot(x, y)
plt.show()

# %%
# 3rd method (recommended)
# Create a Figure and multiple potential Axes and add some data
fig , ax = plt.subplots()
ax.plot([1, 2, 3, 4],[50, 100, 200, 250]); # add some data
type(fig) , type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Anatomy of a Matplotlib figure

# %% [markdown]
# <img src="Images/matplotlib-anatomy-of-a-plot.png" />

# %% [markdown]
# # Matplotlib example Workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
import matplotlib.pyplot as plt 

# 1.prepare  data 
x =  [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2.Setup plot
fig, ax = plt.subplots(figsize=(10,10)) # Height & Width 

# 3.Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title = "Simple Plot", 
      xlabel = "x-axis",
      ylabel = "y-axis")

# 5.Save & show (you save the whole figure)
fig.savefig("Images/sample-plot.png")

# %% [markdown]
# ## Making Figures with Numpy arrays
# We Want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# Plot The data and create a line plot (The default one)
fig , ax =plt.subplots(figsize=(9, 9))
ax.plot(x, x ** 2)

# %% [markdown]
# ## Creating a Scatter plot

# %%
# Use same Data to make a scaatter 
fig , ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig , ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %% [markdown]
# ## Create a Bar Plot

# %%
# Make a plot from dictionary
nut_butter_prices = {
    "Almond butter": 10, 
    "Peanut butter": 8,
    "Cashew butter": 12
}
fig , ax = plt.subplots()
ax.bar(nut_butter_prices.keys() ,nut_butter_prices.values())
ax.set(title = "Dan's Nut Butter Store", 
      ylabel = "Prices ($)")
# Out:
# [Text(0.5, 1.0, "Dan's Nut Butter Store"), Text(0, 0.5, 'Prices ($)')]

# %%
fig , ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Create a Histogram

# %%
# make some data for histogram
x = np.random.randn(1000) # pulls data from a normal distrubution
fig , ax = plt.subplots()
ax.hist(x)
# Out:
# (array([ 21.,  51., 124., 210., 231., 183., 108.,  41.,  25.,   6.]),
#  array([-2.49711725, -1.92118848, -1.34525971, -0.76933094, -0.19340217,
#          0.3825266 ,  0.95845537,  1.53438414,  2.11031291,  2.68624168,
#          3.26217045]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Two Options for Subplots

# %%
#Subplot option 1: Create 4 subplots with each Axes having its own variable name
fig , ((ax1, ax2) , (ax3 , ax4)) = plt.subplots(nrows = 2, # 2 rows 
                                                ncols = 2, # 2 columns 
                                               figsize = (10, 5))
# PLot to each diffrent Axis 
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  9.,  32.,  76., 162., 219., 221., 152.,  85.,  35.,   9.]),
#  array([-2.97911357, -2.39250056, -1.80588755, -1.21927454, -0.63266153,
#         -0.04604852,  0.54056449,  1.1271775 ,  1.71379051,  2.30040352,
#          2.88701653]),
#  <BarContainer object of 10 artists>)

# %%
# Subplots Option 2: Create 4 subplots with a single ax variable 
fig , ax = plt.subplots(nrows = 2, 
                        ncols = 2, 
                       figsize = (10, 5))
#Plot to each different index 
ax[0, 0].plot(x , x / 2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  8.,  28.,  90., 182., 280., 231., 132.,  36.,   9.,   4.]),
#  array([-3.10180281, -2.43868983, -1.77557685, -1.11246388, -0.4493509 ,
#          0.21376208,  0.87687506,  1.53998803,  2.20310101,  2.86621399,
#          3.52932696]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Plotting from Pandas DataFrames

# %%
import pandas as pd

# %%
# make a DataFrame
car_sales = pd.read_csv("Datasets/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), 
              index =pd.date_range("1/1/2000" , periods=1000))
ts = ts.cumsum() # Add up the values cumulatively
ts.plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[$,.]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove the last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range('1/1/2026', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2026-01-01
# 1   Honda    Red          87899      4   5000 2026-01-02
# 2  Toyota   Blue          32549      3   7000 2026-01-03
# 3     BMW  Black          11179      5  22000 2026-01-04
# 4  Nissan  White         213095      4   3500 2026-01-05
# 5  Toyota  Green          99213      4   4500 2026-01-06
# 6   Honda   Blue          45698      4   7500 2026-01-07
# 7   Honda   Blue          54738      4   7000 2026-01-08
# 8  Toyota  White          60000      4   6250 2026-01-09
# 9  Nissan  White          31600      4   9700 2026-01-10

# %%
car_sales["Total Sales"]= car_sales["Price"].astype(int).cumsum() # I want them as int's not string
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500
# 5  Toyota  Green          99213      4   4500 2026-01-06        46000
# 6   Honda   Blue          45698      4   7500 2026-01-07        53500
# 7   Honda   Blue          54738      4   7000 2026-01-08        60500
# 8  Toyota  White          60000      4   6250 2026-01-09        66750
# 9  Nissan  White          31600      4   9700 2026-01-10        76450

# %%
# Let's plot the total sales 
car_sales.plot(x = "Sale Date", y = "Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
car_sales.plot(x = "Odometer (KM)" , y ="Price", kind = "scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Convert Price to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot a scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind='scatter');

# %%
# How about a bar graph
x = np.random.rand(10, 4)
x

#Turn it into a DataFrame 
df = pd.DataFrame(x , columns= ['a' ,'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.003743  0.619802  0.233187  0.460180
# 1  0.074919  0.602280  0.254225  0.169259
# 2  0.542576  0.637789  0.267981  0.777581
# 3  0.854724  0.999815  0.329509  0.964344
# 4  0.918700  0.159642  0.197873  0.842837
# 5  0.627589  0.732799  0.075851  0.792704
# 6  0.670649  0.546451  0.910004  0.611129
# 7  0.916562  0.754964  0.676679  0.941333
# 8  0.681399  0.683953  0.467536  0.879023
# 9  0.453307  0.777003  0.837922  0.716140

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind ="bar")
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500
# 5  Toyota  Green          99213      4   4500 2026-01-06        46000
# 6   Honda   Blue          45698      4   7500 2026-01-07        53500
# 7   Honda   Blue          54738      4   7000 2026-01-08        60500
# 8  Toyota  White          60000      4   6250 2026-01-09        66750
# 9  Nissan  White          31600      4   9700 2026-01-10        76450

# %%
car_sales.plot(x="Make", y = "Odometer (KM)", kind = "bar")
# Out:
# <Axes: xlabel='Make'>

# %%
# How about Histograms ? 

car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Changing the bins parameter we can put our data into different numbers of collections.
car_sales["Odometer (KM)"].plot.hist(bins=20)  # default number of bins (or groups) is 10
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Let's try another dataset
heart_disease =pd.read_csv("Datasets/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histograme for Age columns 
heart_disease.age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.age.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(subplots = True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
heart_disease.plot.hist( figsize =(10, 30), subplots = True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Which one should I use? (pyplot vs matplotlib OO method)
#
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Pyplot method
over_50.plot(x = "age", 
             y ="chol", 
             kind = "scatter", 
             c = "target")  # colour the dots by target value
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
## OO method with pyplot 
# Create a Figure and Axes instance
fig , ax = plt.subplots(figsize = (10, 6))
over_50.plot(x = "age", 
             y ="chol", 
             kind = "scatter", 
             c = "target", 
             ax = ax)  # set the target Axes
# Customize the x-axis limits (to be within our target age ranges)
ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
# OO method from scratch 
fig , ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(x = over_50["age"], 
                     y = over_50["chol"],
                     c = over_50["target"])
# Customize the plot 
ax.set(title = "Heart Disease and Cholesterol Levels", 
       xlabel = "Age", 
       ylabel = "Cholestrol")

# Add a legend
ax.legend(*scatter.legend_elements() , title = "Target")

# Add a horizontal line 
ax.axhline(over_50.chol.mean(), 
           linestyle = '--')

# %%
# Subplots of chol, age, thalach

# Setup plot (2 rows, 1 column)
fig , (ax0 ,ax1) = plt.subplots(nrows = 2, # 2 rows
                                ncols = 1,# 1 column 
                                sharex = True, # both plots should use the same x-axis
                                figsize = (10, 8)) 
                                                    

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data to ax0
scatter = ax0.scatter(x = over_50.age,
                      y = over_50.chol,
                      c = over_50.target )
# Customize ax0
ax0.set(title = "Heart Disease and Cholesterol Levels", 
        ylabel = "Cholistrol")
ax0.legend(*scatter.legend_elements() , title = "Target")

# Setup a mean line
ax0.axhline(y = over_50.chol.mean(), 
           linestyle = "--")

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(x = over_50.age,
                      y = over_50.thalach,
                      c = over_50.target )

# Customize ax1
ax1.set(title = "Heart Disease and Max heart rate", 
        xlabel = "Age", 
        ylabel = "Heart rate")
ax1.legend(*scatter.legend_elements() , title = "Target")

# Setup a mean line
ax1.axhline(y = over_50.thalach.mean(), 
           linestyle = "--")

# Add a title to the figure 
fig.suptitle("Heart disease Analysis" , fontsize = 16, fontweight = "bold")
# Out:
# Text(0.5, 0.98, 'Heart disease Analysis')

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# See the different styles available 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500

# %%
# Plot before changing style
plt.style.use('default')
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8-whitegrid')
car_sales.Price.plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8')
car_sales.Price.plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x = "Odometer (KM)", y ="Price" , kind ="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use('ggplot')
car_sales.Price.plot()
# Out:
# <Axes: >

# %%
# Create some  data 
x = np.random.randn(10 ,4)
x
# Out:
# array([[-0.36171696,  0.50411787,  0.5530967 ,  0.43124964],
#        [ 1.4549546 ,  0.12746053, -0.72809352,  1.33434222],
#        [ 0.8559381 , -0.37169999, -1.1682368 ,  1.81775471],
#        [-2.43487064, -0.48926395, -1.34814098, -1.54358376],
#        [ 0.40515765,  0.88648878,  0.137596  , -0.11240995],
#        [-0.22656467, -0.0946617 , -0.80038624, -2.1541569 ],
#        [-0.68638671,  0.91688308, -1.69252843,  0.90122622],
#        [ 1.49300021,  0.11197462, -0.76897873,  0.81664269],
#        [ 0.03715563, -0.62894177,  0.23613027, -0.19899706],
#        [ 1.20605666, -0.48593745, -0.86918979, -0.83459859]])

# %%
df = pd.DataFrame(x , columns = ["a" , 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.361717  0.504118  0.553097  0.431250
# 1  1.454955  0.127461 -0.728094  1.334342
# 2  0.855938 -0.371700 -1.168237  1.817755
# 3 -2.434871 -0.489264 -1.348141 -1.543584
# 4  0.405158  0.886489  0.137596 -0.112410
# 5 -0.226565 -0.094662 -0.800386 -2.154157
# 6 -0.686387  0.916883 -1.692528  0.901226
# 7  1.493000  0.111975 -0.768979  0.816643
# 8  0.037156 -0.628942  0.236130 -0.198997
# 9  1.206057 -0.485937 -0.869190 -0.834599

# %%
ax = df.plot(kind = 'bar')
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# customize our plot with the set() method
ax = df.plot(kind = "bar")

# add some labels and a title 
ax.set(title ="Random Number Bar Graph from DataFrame",
       xlabel = "Row number",
       ylabel = "Random number")

# Make the legend visible 
ax.legend().set_visible(True)

# %%
#Set the style
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch 
fig , ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(x = over_50["age"], 
                     y = over_50["chol"],
                     c = over_50["target"], 
                     cmap = "winter" ) # Change the colou r scheme 
# Customize the plot 
ax.set(title = "Heart Disease and Cholesterol Levels", 
       xlabel = "Age", 
       ylabel = "Cholestrol")

# Add a legend
ax.legend(*scatter.legend_elements() , title = "Target")

# Add a horizontal line 
ax.axhline(over_50.chol.mean(), 
           linestyle = '--')

# %% [markdown]
# This plot shows some information about the heart disease dataset...

# %%
# Customizing the y and x 

# Subplots of chol, age, thalach

# Setup plot (2 rows, 1 column)
fig , (ax0 ,ax1) = plt.subplots(nrows = 2, # 2 rows
                                ncols = 1,# 1 column 
                                sharex = True, # both plots should use the same x-axis
                                figsize = (10, 8)) 
                                                    

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data to ax0
scatter = ax0.scatter(x = over_50.age,
                      y = over_50.chol,
                      c = over_50.target,
                      cmap = 'winter')
# Customize ax0
ax0.set(title = "Heart Disease and Cholesterol Levels", 
        ylabel = "Cholistrol")
ax0.legend(*scatter.legend_elements() , title = "Target")
# Change ax0  axis limits
ax0.set_xlim([50, 80])
ax0.set_ylim([100 , 450])
# Setup a mean line
ax0.axhline(y = over_50.chol.mean(), 
           linestyle = "--")

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(x = over_50.age,
                      y = over_50.thalach,
                      c = over_50.target, 
                      cmap = 'winter')

# Customize ax1
ax1.set(title = "Heart Disease and Max heart rate", 
        xlabel = "Age", 
        ylabel = "Heart rate")
ax1.legend(*scatter.legend_elements() , title = "Target")

ax1.set_ylim([60 , 200])
 
# Setup a mean line
ax1.axhline(y = over_50.thalach.mean(), 
           linestyle = "--")

# Add a title to the figure 
fig.suptitle("Heart disease Analysis" , fontsize = 16, fontweight = "bold")
# Out:
# Text(0.5, 0.98, 'Heart disease Analysis')

# %%
fig.savefig("Images/heart-disease-analysis-plot.png")
